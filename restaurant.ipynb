# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Load the restaurant data
csv_file = os.path.join("resources", "restaurant_data.csv")

restaurant_df = pd.read_csv(csv_file, encoding = 'utf-8')
restaurant_df.head(10)
# Out:
#            Name  Location   Cuisine  Rating  Seating Capacity  \
# 0  Restaurant 0     Rural  Japanese     4.0                38
# 1  Restaurant 1  Downtown   Mexican     3.2                76
# 2  Restaurant 2     Rural   Italian     4.7                48
# 3  Restaurant 3     Rural   Italian     4.4                34
# 4  Restaurant 4  Downtown  Japanese     4.9                88
# 5  Restaurant 5  Downtown    Indian     4.4                79
# 6  Restaurant 6     Rural   Mexican     4.9                49
# 7  Restaurant 7  Suburban  Japanese     4.1                61
# 8  Restaurant 8     Rural  Japanese     4.2                37
# 9  Restaurant 9     Rural    French     5.0                32
#
#    Average Meal Price  Marketing Budget  Social Media Followers  \
# 0               73.98              2224                   23406
# 1               28.11              4416                   42741
# 2               48.29              2796                   37285
# 3               51.55              1167                   15214
# 4               75.98              3639                   40171
# 5               35.69              6787                   75378
# 6               35.30              2594                   32587
# 7               73.65              3213                   33429
# 8               73.75              3437                   37102
# 9               59.80              2569                   28419
#
#    Chef Experience Years  Number of Reviews  Avg Review Length  \
# 0                     13                185         161.924906
# 1                      8                533         148.759717
# 2                     18                853          56.849189
# 3                     13                 82         205.433265
# 4                      9                 78         241.681584
# 5                      5                400         247.544461
# 6                     11                106         206.159035
# 7                     14                377         135.319312
# 8                     18                494          55.652417
# 9                     18                907         273.944887
#
#    Ambience Score  Service Quality Score Parking Availability  \
# 0             1.3                    7.0                  Yes
# 1             2.6                    3.4                  Yes
# 2             5.3                    6.7                   No
# 3             4.6                    2.8                  Yes
# 4             8.6                    2.1                   No
# 5             2.0                    8.5                  Yes
# 6             1.5                    5.3                   No
# 7             1.8                    4.6                   No
# 8             7.1                    9.4                  Yes
# 9             6.4                    7.4                   No
#
#    Weekend Reservations  Weekday Reservations     Revenue
# 0                    13                     4   638945.52
# 1                    48                     6   490207.83
# 2                    27                    14   541368.62
# 3                     9                    17   404556.80
# 4                    37                    26  1491046.35
# 5                    27                    22   644220.90
# 6                    12                    28   400348.65
# 7                    56                    23  1014153.65
# 8                    27                    24   635606.10
# 9                    12                    19   452920.65

# %%
# Check for missing data
restaurant_df.count()
# Out:
# Name                      8368
# Location                  8368
# Cuisine                   8368
# Rating                    8368
# Seating Capacity          8368
# Average Meal Price        8368
# Marketing Budget          8368
# Social Media Followers    8368
# Chef Experience Years     8368
# Number of Reviews         8368
# Avg Review Length         8368
# Ambience Score            8368
# Service Quality Score     8368
# Parking Availability      8368
# Weekend Reservations      8368
# Weekday Reservations      8368
# Revenue                   8368
# dtype: int64

# %%
# Check data types
restaurant_df.dtypes
# Out:
# Name                       object
# Location                   object
# Cuisine                    object
# Rating                    float64
# Seating Capacity            int64
# Average Meal Price        float64
# Marketing Budget            int64
# Social Media Followers      int64
# Chef Experience Years       int64
# Number of Reviews           int64
# Avg Review Length         float64
# Ambience Score            float64
# Service Quality Score     float64
# Parking Availability       object
# Weekend Reservations        int64
# Weekday Reservations        int64
# Revenue                   float64
# dtype: object

# %%
# Create a country list for x-axis
country_list = ["American", "French", "Indian", "Italian", "Japanese", "Mexican"]

# %% [markdown]
# 1. Average "Revenue" comparison by each country's "Cuisine"

# %%
# Group with "Cuisine" by each countries with average "Revenue"
group0 = restaurant_df.groupby(["Cuisine"])
group0 = group0[["Revenue"]].mean()
group0
# Out:
#                 Revenue
# Cuisine
# American  564942.031518
# French    820204.107132
# Indian    496615.723944
# Italian   692742.385796
# Japanese  937969.038810
# Mexican   427383.895621

# %%
# Create a "Revenue" list 
revenue = group0["Revenue"].tolist()
revenue
# Out:
# [564942.0315183615,
#  820204.1071318911,
#  496615.7239444851,
#  692742.3857961784,
#  937969.0388095239,
#  427383.89562096196]

# %%
# Create a bar chart comparing average "Revenue" by each countries
plt.bar(country_list, revenue, color = 'orange')

plt.title("Comparison between countries (Average Revenue)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Average Revenue")

revenue_bar_path = os.path.join("results", "avg_revenue_bar_comparison.png")
plt.savefig(revenue_bar_path)

# %%
# Create a pie chart comparing average "Revenue" by each countries
country_list = ["American", "French", "Indian", "Italian", "Japanese", "Mexican"]
colors = ["lightblue", "red", "green", "orange", "yellow", "pink"]
explode = (0, 0, 0, 0, 0.1, 0)
figure = revenue

plt.pie(figure, labels = country_list, colors = colors, explode = explode, 
        shadow = True, autopct = '%.1f%%', startangle = 120)
plt.title("Comparison between countries (Average Revenue)")

revenue_pie_path = os.path.join("results", "avg_revenue_pie_comparison.png")
plt.savefig(revenue_pie_path)

# %%
# Create a line graph comparing average "Revenue" by each countries
plt.plot(country_list, revenue, marker = 'o', color = 'green', label = "Average Revenue")

plt.title("Comparison between countries (Average Revenue)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Average Revenue")
plt.legend(loc = 'best')

revenue_line_path = os.path.join("results", "avg_revenue_line_comparison.png")
plt.savefig(revenue_line_path)

# %% [markdown]
# 2. Average "Rating" by each country's "Cuisine"

# %%
# Group with "Cuisine" by each countries with average "Rating" scores
group1 = restaurant_df.groupby(["Cuisine"])
group1 = group1[["Rating"]].mean()
group1
# Out:
#             Rating
# Cuisine
# American  3.992302
# French    4.000977
# Indian    4.012856
# Italian   4.014650
# Japanese  4.012574
# Mexican   4.016798

# %%
# Create a "Rating" list
rating = group1["Rating"].tolist()
rating
# Out:
# [3.9923022598870057,
#  4.0009769713886945,
#  4.012856099342586,
#  4.014649681528662,
#  4.012574404761905,
#  4.0167982770997845]

# %%
# Create a bar chart comparing average "Rating" by each countries
plt.bar(country_list, rating, color = 'orange')

plt.title("Comparison between countries (Average Rating)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Average Rating Scores")

rating_path = os.path.join("results", "avg_rating_bar_comparison.png")
plt.savefig(rating_path)

# %%
# Create a pie chart comparing average "Rating" by each countries
country_list = ["American", "French", "Indian", "Italian", "Japanese", "Mexican"]
colors = ["lightblue", "red", "green", "orange", "yellow", "pink"]
explode = (0, 0, 0, 0, 0, 0.1)
figure = rating

plt.pie(figure, labels = country_list, colors = colors, explode = explode, 
        shadow = True, autopct = '%.1f%%', startangle = 70)
plt.title("Comparison between countries (Average Rating)")

rating_pie_path = os.path.join("results", "avg_rating_pie_comparison.png")
plt.savefig(rating_pie_path)

# %%
# Create a line graph comparing average "Rating" by each countries
plt.plot(country_list, rating, marker = 'o', color = 'green', label = "Average Rating Score")

plt.title("Comparison between countries (Average Rating)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Average Rating Scores")
plt.legend(loc = 'best')

rating_path = os.path.join("results", "avg_rating_line_comparison.png")
plt.savefig(rating_path)

# %% [markdown]
# 3. Average "Service Quality Score" by each country's "Cuisine"

# %%
# Group with "Cuisine" by each countries with average "Service Quality Score"
group2 = restaurant_df.groupby(["Cuisine"])
group2 = group2[["Service Quality Score"]].mean()
group2
# Out:
#           Service Quality Score
# Cuisine
# American               5.543291
# French                 5.468597
# Indian                 5.465888
# Italian                5.429512
# Japanese               5.641964
# Mexican                5.509045

# %%
# Create a "Service Quality Score" list
service_quality_score = group2["Service Quality Score"].tolist()
service_quality_score
# Out:
# [5.543290960451977,
#  5.468597348220516,
#  5.465887509130752,
#  5.4295116772823775,
#  5.641964285714286,
#  5.509045226130653]

# %%
# Create a bar chart comparing average "Service Quality Score" by each countries
plt.bar(country_list, service_quality_score, color = 'orange')

plt.title("Comparison between countries (Average Service Quality Score)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Average Service Quality Scores")

service_q_score_bar_path = os.path.join("results", "avg_service_quality_bar_comparison.png")
plt.savefig(service_q_score_bar_path)

# %%
# Create a pie chart comparing average "Service Quality Score" by each countries
country_list = ["American", "French", "Indian", "Italian", "Japanese", "Mexican"]
colors = ["lightblue", "red", "green", "orange", "yellow", "pink"]
explode = (0, 0, 0, 0, 0.1, 0)
figure = rating

plt.pie(figure, labels = country_list, colors = colors, explode = explode, 
        shadow = True, autopct = '%.1f%%', startangle = 120)

plt.title("Comparison between countries (Average Service Quality Score)")

service_q_score_pie_path = os.path.join("results", "avg_service_quality_pie_comparison.png")
plt.savefig(service_q_score_pie_path)

# %%
# Create a line graph comparing average "Service Quality Score" by each countries
plt.plot(country_list, service_quality_score, marker = 'o', color = 'green', label = "Average Service Quality Score")

plt.title("Comparison between countries (Average Service Quality Score)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Average Service Quality Scores")
plt.legend(loc = 'best')

service_q_score_line_path_ = os.path.join("results", "avg_service_quality_line_comparison.png")
plt.savefig(service_q_score_line_path_)

# %% [markdown]
# 4. Average "Weekend Reservations", "Weekday Reservations", and "Weekend Reservations" by each country's "Cuisine"

# %%
# Group with "Cuisine" by each countries with average "Weekend Reservations" and "Weekday Reservations"
group3 = restaurant_df.groupby(["Cuisine"])
group3 = group3[["Weekend Reservations", "Weekday Reservations"]].mean()
group3
# Out:
#           Weekend Reservations  Weekday Reservations
# Cuisine
# American             29.832627             29.594633
# French               29.450803             28.926029
# Indian               29.733382             30.209642
# Italian              29.654636             29.310686
# Japanese             28.534970             27.842262
# Mexican              29.707825             29.498205

# %%
# Create a "Weekend Reservations" list
weekend = group3["Weekend Reservations"].tolist()
weekend
# Out:
# [29.83262711864407,
#  29.450802512212142,
#  29.733382030679326,
#  29.65463552724699,
#  28.534970238095237,
#  29.707824838478103]

# %%
# Create a "Weekday Reservations" list
weekday = group3["Weekday Reservations"].tolist()
weekday
# Out:
# [29.59463276836158,
#  28.92602930914166,
#  30.209642074506938,
#  29.310686482661005,
#  27.842261904761905,
#  29.498205312275665]

# %%
# Create a line graph comparing average "Weekend Reservations" and average "Weekday Reservations" by each countries
plt.plot(country_list, weekend, marker = 'o', color = 'red', label = 'Average Weekday Reservation')
plt.plot(country_list, weekday, marker = 'o', color = 'blue', label = 'Average Weekend Reservation')

plt.title("Comparison between countries (Average Weekdays and Weekend Reservations)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Average Reservations")
plt.legend(loc = 'best')

weekend_weekday_path = os.path.join("results", "avg_weekend_weekday_line_comparison.png")
plt.savefig(weekend_weekday_path)

# %%
group3["Week Reservations"] = group3["Weekend Reservations"] + group3["Weekday Reservations"]
group3
# Out:
#           Weekend Reservations  Weekday Reservations  Week Reservations
# Cuisine
# American             29.832627             29.594633          59.427260
# French               29.450803             28.926029          58.376832
# Indian               29.733382             30.209642          59.943024
# Italian              29.654636             29.310686          58.965322
# Japanese             28.534970             27.842262          56.377232
# Mexican              29.707825             29.498205          59.206030

# %%
# Create a "Week Reservations" list
week = group3["Week Reservations"].tolist()
week
# Out:
# [59.42725988700565,
#  58.376831821353804,
#  59.94302410518627,
#  58.96532200990799,
#  56.37723214285714,
#  59.20603015075377]

# %%
# Create a line graph comparing average "Week Reservations" by each countries
plt.plot(country_list, week, marker = 'o', color = 'green', label = "Average Week Reservation")

plt.title("Comparison between countries (Average Week Reservations)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Average Reservations")
plt.legend(loc = 'best')

week_path = os.path.join("results", "avg_week_line_comparison.png")
plt.savefig(week_path)

# %%
# Create a pie chart comparing average "Week Reservations" by each countries
country_list = ["American", "French", "Indian", "Italian", "Japanese", "Mexican"]
colors = ["lightblue", "red", "green", "orange", "yellow", "pink"]
explode = (0, 0, 0.1, 0, 0, 0)
figure = rating

plt.pie(figure, labels = country_list, colors = colors, explode = explode, 
        shadow = True, autopct = '%.1f%%', startangle = 250)

plt.title("Comparison between countries (Average Week Reservations)")

week_pie_path = os.path.join("results", "avg_week_pie_comparison.png")
plt.savefig(week_pie_path)

# %% [markdown]
# 5. Total (sum) "Revenue" by each country's "Cuisine"

# %%
# Group with "Cuisine" by each countries with total (sum) "Revenue"
group4 = restaurant_df.groupby(["Cuisine"])
group4 = group4[["Revenue"]].sum()
group4
# Out:
#                Revenue
# Cuisine
# American  7.999579e+08
# French    1.175352e+09
# Indian    6.798669e+08
# Italian   9.788450e+08
# Japanese  1.260630e+09
# Mexican   5.953458e+08

# %%
# Create a "Revenue" list 
revenue = group4["Revenue"].tolist()
revenue
# Out:
# [799957916.63,
#  1175352485.52,
#  679866926.08,
#  978844991.13,
#  1260630388.16,
#  595345766.6]

# %%
# Create a bar chart comparing total (sum) "Revenue" by each countries
plt.bar(country_list, revenue, color = 'orange')

plt.title("Comparison between countries (Total (sum) Revenue)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Total (sum) Revenue")

revenue_sum_bar_path = os.path.join("results", "sum_revenue_bar_comparison.png")
plt.savefig(revenue_sum_bar_path)

# %%
# Create a pie chart comparing total (sum) "Revenue" by each countries
country_list = ["American", "French", "Indian", "Italian", "Japanese", "Mexican"]
colors = ["lightblue", "red", "green", "orange", "yellow", "pink"]
explode = (0, 0, 0, 0, 0.1, 0)
figure = revenue

plt.pie(figure, labels = country_list, colors = colors, explode = explode, 
        shadow = True, autopct = '%.1f%%', startangle = 120)
plt.title("Comparison between countries (Total (sum) Revenue)")

revenue_sum_pie_path = os.path.join("results", "sum_revenue_pie_comparison.png")
plt.savefig(revenue_sum_pie_path)

# %%
# Create a line graph comparing total (sum) "Revenue" by each countries
plt.plot(country_list, revenue, marker = 'o', color = 'green', label = "Total (sum) Revenue")

plt.title("Comparison between countries (Total (sum) Revenue)")
plt.xlabel("Cuisine by each countries")
plt.ylabel("Total (sum) Revenue")
plt.legend(loc = 'best')

revenue_sum_line_path = os.path.join("results", "sum_revenue_line_comparison.png")
plt.savefig(revenue_sum_line_path)
